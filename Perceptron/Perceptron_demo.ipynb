# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
df = pd.read_csv(r'D:\DeepLearning\DataSets\Placement.csv')

# %%
df.head()
# Out:
#    cgpa  iq  placed
# 0   4.0  60       0
# 1   4.1  62       0
# 2   4.2  64       0
# 3   4.3  66       0
# 4   4.4  68       0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cgpa    150 non-null    float64
#  1   iq      150 non-null    int64
#  2   placed  150 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 3.6 KB

# %%
df.describe()
# Out:
#              cgpa          iq      placed
# count  150.000000  150.000000  150.000000
# mean     6.590000  112.660000    0.500000
# std      1.633161   31.501322    0.501675
# min      4.000000   60.000000    0.000000
# 25%      5.200000   84.000000    0.000000
# 50%      6.500000  110.500000    0.500000
# 75%      7.900000  138.750000    1.000000
# max      9.800000  170.000000    1.000000

# %%
df.shape
# Out:
# (150, 3)

# %%
sns.scatterplot(x= df['cgpa'] , y = df['iq'] , hue=df['placed'])
plt.plot()
# Out:
# []

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#      cgpa   iq
# 0     4.0   60
# 1     4.1   62
# 2     4.2   64
# 3     4.3   66
# 4     4.4   68
# ..    ...  ...
# 145   9.3  165
# 146   9.4  167
# 147   9.5  169
# 148   9.6  168
# 149   9.8  170
#
# [150 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    1
# 146    1
# 147    1
# 148    1
# 149    1
# Name: placed, Length: 150, dtype: int64

# %%
from sklearn.linear_model import Perceptron

# %%
s = Perceptron(random_state=0, tol=None, max_iter=10000)

# %%
s.fit(X,y)
# Out:
# Perceptron(max_iter=10000, tol=None)

# %%
s.coef_
# Out:
# array([[-1098.7,   331. ]])

# %%
s.intercept_
# Out:
# array([-29269.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values , y.values , clf = s , legend = 2)
# Out:
# d:\DeepLearning\venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
